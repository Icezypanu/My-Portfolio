# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
import scipy.stats as stats

# %%
data = pd.read_csv('C:/Users/CS_Lab/Downloads/archive/car data.csv')
data.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
data['Selling_Price'].hist(bins=10)
# Out:
# <Axes: >

# %%
data[['Transmission', 'Fuel_Type', 'Seller_Type']].nunique()
# Out:
# Transmission    2
# Fuel_Type       3
# Seller_Type     2
# dtype: int64

# %%
data[['Transmission', 'Fuel_Type', 'Seller_Type']].nunique().plot.bar(figsize=(12,6))
plt.ylabel('Number of unique categories')
plt.xlabel('Variables')
plt.title('Cardinality')
# Out:
# Text(0.5, 1.0, 'Cardinality')

# %%
stats.probplot(data['Selling_Price'], dist='norm', plot=plt)
plt.show()

# %%
stats.probplot(data['Present_Price'], dist='norm', plot=plt)
plt.show()

# %%
stats.probplot(data['Kms_Driven'], dist='norm', plot=plt)
plt.show()

# %%
sns.distplot(data['Selling_Price'], bins=30)
# Out:
# C:\Users\CS_Lab\AppData\Local\Temp\ipykernel_10644\3559734703.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Selling_Price'], bins=30)
# <Axes: xlabel='Selling_Price', ylabel='Density'>
