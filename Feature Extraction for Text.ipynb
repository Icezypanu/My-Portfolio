# %%
import pandas as pd
import numpy as np
import string
import nltk
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data = pd.read_csv('Twitter_Data.csv')
data.head()
# Out:
#                                           clean_text  category
# 0  when modi promised “minimum government maximum...      -1.0
# 1  talk all the nonsense and continue all the dra...       0.0
# 2  what did just say vote for modi  welcome bjp t...       1.0
# 3  asking his supporters prefix chowkidar their n...       1.0
# 4  answer who among these the most powerful world...       1.0

# %%
data.dropna(inplace=True)

# %%
data.head()
# Out:
#                                           clean_text  category
# 0  when modi promised “minimum government maximum...      -1.0
# 1  talk all the nonsense and continue all the dra...       0.0
# 2  what did just say vote for modi  welcome bjp t...       1.0
# 3  asking his supporters prefix chowkidar their n...       1.0
# 4  answer who among these the most powerful world...       1.0

# %%
text = data['clean_text'][0]
text
# Out:
# 'when modi promised “minimum government maximum governance” expected him begin the difficult job reforming the state why does take years get justice state should and not business and should exit psus and temples'

# %%
text = text = text.lower()

# %%
tokens = nltk.tokenize.word_tokenize(text)

# %%
punctuationSet = [c for c in string.punctuation]+['’','“','”']
tokenRemovedNuisance = []
for token in tokens:
  if token not in punctuationSet:
    tokenRemovedNuisance.append(token)

# %%
print(tokenRemovedNuisance)
# Out:
# ['when', 'modi', 'promised', 'minimum', 'government', 'maximum', 'governance', 'expected', 'him', 'begin', 'the', 'difficult', 'job', 'reforming', 'the', 'state', 'why', 'does', 'take', 'years', 'get', 'justice', 'state', 'should', 'and', 'not', 'business', 'and', 'should', 'exit', 'psus', 'and', 'temples']

# %%
pst = nltk.stem.PorterStemmer()
StemmingWord = []
for word in tokenRemovedNuisance:
  stw = pst.stem(word)
  StemmingWord.append(stw)

# %%
def my_preprocessing(text):
  text = text = text.lower()
  tokens = nltk.tokenize.word_tokenize(text)
  punctuationSet = [c for c in string.punctuation]+['’','“','”']
  tokenRemovedNuisance = []
  for token in tokens:
    if token not in punctuationSet:
      tokenRemovedNuisance.append(token)
  pst = nltk.stem.PorterStemmer()
  StemmingWord = []
  for word in tokenRemovedNuisance:
    stw = pst.stem(word)
    StemmingWord.append(stw)
  return ' '.join(StemmingWord)

# %%
copus = data["clean_text"].values.tolist()

# %%
cv = CountVectorizer()
count_vector = cv.fit_transform(copus)

# %%
vocab_dicts = {'cat': 0, 'dog': 1, 'fish':2, 'tiger':3}
cv = CountVectorizer(vocabulary=vocab_dicts)
count_vector = cv.fit_transform(copus)

# %%
count_vector.shape
# Out:
# (162969, 4)

# %%
def my_tokenizer(text):
  # create a space between special characters
  text=re.sub("(\\W)"," \\1 ",text)
  # split based on whitespace
  return re.split("\\s+",text)
cv = CountVectorizer(tokenizer=my_tokenizer)
count_vector=cv.fit_transform(copus)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
count_vector.shape
# Out:
# (162969, 107196)

# %%
stop_words = ["all","in","the","is","and"]
cv = CountVectorizer(stop_words = stop_words)
count_vector=cv.fit_transform(copus)

# %%
cv = CountVectorizer(preprocessor = my_preprocessing)
count_vector=cv.fit_transform(copus)

# %%
cv = CountVectorizer(ngram_range=(1,2))
count_vector=cv.fit_transform(copus)

# %%
cv = CountVectorizer(ngram_range=(1,2), max_features=20)
count_vector=cv.fit_transform(copus)
print(cv.vocabulary_)
# Out:
# {'modi': 10, 'the': 13, 'and': 1, 'not': 11, 'all': 0, 'will': 17, 'for': 4, 'you': 19, 'his': 8, 'are': 2, 'from': 5, 'this': 15, 'has': 6, 'with': 18, 'india': 9, 'was': 16, 'that': 12, 'but': 3, 'have': 7, 'they': 14}

# %% [markdown]
# **LAB 7**

# %%
data = pd.read_csv('spam.csv', encoding='latin')
data.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
data.drop(['Unnamed: 2','Unnamed: 3','Unnamed: 4'], axis=1, inplace = True)

# %%
data.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
X, y = data[['v2']], data['v1']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.head()
# Out:
#                                                      v2
# 708   To review and KEEP the fantastic Nokia N-Gage ...
# 4338                 Just got outta class gonna go gym.
# 5029  Is there coming friday is leave for pongal?do ...
# 4921  Hi Dear Call me its urgnt. I don't know whats ...
# 2592  My friend just got here and says he's upping h...

# %%
copus_train = X_train['v2'].values.tolist()
tfidfv = TfidfVectorizer(preprocessor=my_preprocessing,ngram_range=(1,2), max_features=50)
tfidf_vector_train = tfidfv.fit(copus_train)
tfidf_vector_train = tfidfv.transform(copus_train)
print(cv.vocabulary_)
# Out:
# {'modi': 10, 'the': 13, 'and': 1, 'not': 11, 'all': 0, 'will': 17, 'for': 4, 'you': 19, 'his': 8, 'are': 2, 'from': 5, 'this': 15, 'has': 6, 'with': 18, 'india': 9, 'was': 16, 'that': 12, 'but': 3, 'have': 7, 'they': 14}

# %%
copus_test = X_test['v2'].values.tolist()
tfidf_vector_test = tfidfv.transform(copus_test)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(tfidf_vector_train,  y_train)
# Out:
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
y_pred = clf.predict(tfidf_vector_test)

# %%
from sklearn.metrics import accuracy_score
print(round(accuracy_score(y_test, y_pred) * 100,3),'%')
# Out:
# 87.201 %

# %%
# !pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in /usr/local/lib/python3.10/dist-packages (0.2.12)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.66.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.3.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.0.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.7.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.10.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->lazypredict) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->lazypredict) (1.16.0)

# %%
from lazypredict.Supervised import LazyClassifier

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
#models,predictions = clf.fit(tfidf_vector_train, tfidf_vector_test, y_train, y_test)
models, prediction = clf.fit(tfidf_vector_train.toarray(), tfidf_vector_test.toarray(), y_train, y_test)
print(models)
# Out:
#  90%|████████▉ | 26/29 [00:13<00:01,  1.56it/s]
# [LightGBM] [Info] Number of positive: 528, number of negative: 3372
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002731 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5348
# [LightGBM] [Info] Number of data points in the train set: 3900, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.135385 -> initscore=-1.854165
# [LightGBM] [Info] Start training from score -1.854165
# 100%|██████████| 29/29 [00:14<00:00,  1.99it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.96               0.87    None      0.96
# ExtraTreesClassifier               0.96               0.86    None      0.96
# NearestCentroid                    0.89               0.85    None      0.90
# LabelPropagation                   0.95               0.85    None      0.94
# LabelSpreading                     0.95               0.85    None      0.94
# RandomForestClassifier             0.95               0.85    None      0.95
# DecisionTreeClassifier             0.93               0.84    None      0.93
# BaggingClassifier                  0.94               0.84    None      0.94
# ExtraTreeClassifier                0.92               0.83    None      0.92
# SVC                                0.95               0.83    None      0.95
# AdaBoostClassifier                 0.94               0.83    None      0.94
# LogisticRegression                 0.94               0.82    None      0.94
# CalibratedClassifierCV             0.94               0.82    None      0.94
# PassiveAggressiveClassifier        0.91               0.82    None      0.91
# LinearSVC                          0.94               0.82    None      0.94
# BernoulliNB                        0.93               0.81    None      0.93
# LinearDiscriminantAnalysis         0.93               0.81    None      0.93
# KNeighborsClassifier               0.94               0.80    None      0.93
# SGDClassifier                      0.92               0.80    None      0.92
# RidgeClassifier                    0.93               0.77    None      0.92
# RidgeClassifierCV                  0.93               0.77    None      0.92
# Perceptron                         0.90               0.76    None      0.90
# GaussianNB                         0.57               0.73    None      0.64
# QuadraticDiscriminantAnalysis      0.71               0.71    None      0.76
# DummyClassifier                    0.87               0.50    None      0.81
#
#                                Time Taken
# Model
# LGBMClassifier                       0.79
# ExtraTreesClassifier                 0.62
# NearestCentroid                      0.13
# LabelPropagation                     1.51
# LabelSpreading                       2.13
# RandomForestClassifier               2.74
# DecisionTreeClassifier               0.09
# BaggingClassifier                    0.39
# ExtraTreeClassifier                  0.06
# SVC                                  0.93
# AdaBoostClassifier                   0.61
# LogisticRegression                   0.23
# CalibratedClassifierCV               1.55
# PassiveAggressiveClassifier          0.19
# LinearSVC                            0.61
# BernoulliNB                          0.08
# LinearDiscriminantAnalysis           0.26
# KNeighborsClassifier                 0.17
# SGDClassifier                        0.30
# RidgeClassifier                      0.22
# RidgeClassifierCV                    0.33
# Perceptron                           0.12
# GaussianNB                           0.06
# QuadraticDiscriminantAnalysis        0.14
# DummyClassifier                      0.05

# %%
prediction
# Out:
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.96               0.87    None      0.96
# ExtraTreesClassifier               0.96               0.86    None      0.96
# NearestCentroid                    0.89               0.85    None      0.90
# LabelPropagation                   0.95               0.85    None      0.94
# LabelSpreading                     0.95               0.85    None      0.94
# RandomForestClassifier             0.95               0.85    None      0.95
# DecisionTreeClassifier             0.93               0.84    None      0.93
# BaggingClassifier                  0.94               0.84    None      0.94
# ExtraTreeClassifier                0.92               0.83    None      0.92
# SVC                                0.95               0.83    None      0.95
# AdaBoostClassifier                 0.94               0.83    None      0.94
# LogisticRegression                 0.94               0.82    None      0.94
# CalibratedClassifierCV             0.94               0.82    None      0.94
# PassiveAggressiveClassifier        0.91               0.82    None      0.91
# LinearSVC                          0.94               0.82    None      0.94
# BernoulliNB                        0.93               0.81    None      0.93
# LinearDiscriminantAnalysis         0.93               0.81    None      0.93
# KNeighborsClassifier               0.94               0.80    None      0.93
# SGDClassifier                      0.92               0.80    None      0.92
# RidgeClassifier                    0.93               0.77    None      0.92
# RidgeClassifierCV                  0.93               0.77    None      0.92
# Perceptron                         0.90               0.76    None      0.90
# GaussianNB                         0.57               0.73    None      0.64
# QuadraticDiscriminantAnalysis      0.71               0.71    None      0.76
# DummyClassifier                    0.87               0.50    None      0.81
#
#                                Time Taken
# Model
# LGBMClassifier                       0.79
# ExtraTreesClassifier                 0.62
# NearestCentroid                      0.13
# LabelPropagation                     1.51
# LabelSpreading                       2.13
# RandomForestClassifier               2.74
# DecisionTreeClassifier               0.09
# BaggingClassifier                    0.39
# ExtraTreeClassifier                  0.06
# SVC                                  0.93
# AdaBoostClassifier                   0.61
# LogisticRegression                   0.23
# CalibratedClassifierCV               1.55
# PassiveAggressiveClassifier          0.19
# LinearSVC                            0.61
# BernoulliNB                          0.08
# LinearDiscriminantAnalysis           0.26
# KNeighborsClassifier                 0.17
# SGDClassifier                        0.30
# RidgeClassifier                      0.22
# RidgeClassifierCV                    0.33
# Perceptron                           0.12
# GaussianNB                           0.06
# QuadraticDiscriminantAnalysis        0.14
# DummyClassifier                      0.05
