# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/netflix.csv')
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
print(f'number of rows:{df.shape[0]} \nnumber of columns:{df.shape[1]}')
# Out:
# number of rows:7789
# number of columns:11

# %%
print(f'columns name:{df.columns.values}')
# Out:
# columns name:['Show_Id' 'Category' 'Title' 'Director' 'Cast' 'Country' 'Release_Date'
#  'Rating' 'Duration' 'Type' 'Description']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# **Duplicate values**

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# **Null Values**

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %% [markdown]
# **Finding Category TV Show**

# %%
df[df['Category'].isin(['TV Show'])]
# Out:
#      Show_Id Category            Title            Director  \
# 5         s6  TV Show               46         Serdar Akar
# 132     s133  TV Show        7 (Seven)         Nizar Shafi
# 218     s219  TV Show  A Queen Is Born        Carla Barros
# 260     s261  TV Show         A.I.C.O.       Kazuya Murata
# 276     s277  TV Show     Abby Hatcher         Kyran Kelly
# ...      ...      ...              ...                 ...
# 7387   s7386  TV Show          Valeria       Inma Torrente
# 7402   s7401  TV Show           Velvet        Carlos Sedes
# 7494   s7493  TV Show   Watership Down          Noam Murro
# 7668   s7667  TV Show    World of Winx      Iginio Straffi
# 7723   s7722  TV Show              You  Lee Toland Krieger
#
#                                                    Cast  \
# 5     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# 132   Rahman, Havish, Regina Cassandra, Nandita Swet...
# 218                       Gloria Groove, Alexia Twister
# ...

# %%
df[df['Category'].str.contains('TV Show')]
# Out:
#      Show_Id Category            Title            Director  \
# 5         s6  TV Show               46         Serdar Akar
# 132     s133  TV Show        7 (Seven)         Nizar Shafi
# 218     s219  TV Show  A Queen Is Born        Carla Barros
# 260     s261  TV Show         A.I.C.O.       Kazuya Murata
# 276     s277  TV Show     Abby Hatcher         Kyran Kelly
# ...      ...      ...              ...                 ...
# 7387   s7386  TV Show          Valeria       Inma Torrente
# 7402   s7401  TV Show           Velvet        Carlos Sedes
# 7494   s7493  TV Show   Watership Down          Noam Murro
# 7668   s7667  TV Show    World of Winx      Iginio Straffi
# 7723   s7722  TV Show              You  Lee Toland Krieger
#
#                                                    Cast  \
# 5     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# 132   Rahman, Havish, Regina Cassandra, Nandita Swet...
# 218                       Gloria Groove, Alexia Twister
# ...

# %% [markdown]
# **Convert columns Release_Date into datetime**

# %%
df['Release_Date'] = pd.to_datetime(df['Release_Date'])

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# year                   float64
# dtype: object

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#   Release_Date Rating  Duration  \
# 1   2016-12-23  TV-MA    93 min
# 2   2018-12-20      R    78 min
# 3   2017-11-16  PG-13    80 min
# 4   2020-01-01  PG-13   123 min
# 5   2017-07-01  TV-MA  1 Season
#
#                                                 Type  \
# ...

# %%
df['Release_Date'].dt.year.value_counts()
# Out:
# 2019    1337
# 2020    1229
# 2018    1115
# 2017     752
# 2016     207
# 2021      78
# 2015      50
# 2014      14
# 2011      13
# 2013       7
# 2012       3
# 2009       2
# 2010       1
# 2008       1
# Name: Release_Date, dtype: int64

# %% [markdown]
# **Show the hightest moveie each year**

# %%
df['Release_Date'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# **How many movies and TV show**

# %%
df.groupby('Category')['Category'].count()
# Out:
# Category
# Movie      4673
# TV Show     136
# Name: Category, dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Movie      4673
# TV Show     136
# Name: Category, dtype: int64

# %%
sns.countplot(data=df, x='Category')
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
df['year'] = df['Release_Date'].dt.year

# %%
df[(df['Category'] == 'Movie') & (df['year'] == 2020)]
# Out:
#      Show_Id Category                          Title  \
# 4         s5    Movie                             21
# 6         s7    Movie                            122
# 14       s15    Movie                           3022
# 27       s28    Movie                         #Alive
# 28       s29    Movie  #AnneFrank - Parallel Stories
# ...      ...      ...                            ...
# 7746   s7745    Movie    Yours Sincerely, Kanan Gill
# 7750   s7749    Movie                      الف مبروك
# 7762   s7761    Movie                      Zaki Chan
# 7783   s7782    Movie                           Zoom
# 7784   s7783    Movie                           Zozo
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# 28    Sabina Fedeli, Anna Migotto
# ...                           ...
# 7746                 Neville Shah
# 7750            Ahmed Nader Galal
# ...

# %% [markdown]
# **Show Title of all TV shows that were released in India**

# %%
df[(df['Category'] == 'TV Show') & (df['Country'] == 'India')]['Title']
# Out:
# 132                                 7 (Seven)
# 2406                                    GHOUL
# 3119             Jamtara - Sabka Number Ayega
# 4724                          Paava Kadhaigal
# 6037    Th Eena Meena Deeka Chase Comedy Show
# Name: Title, dtype: object

# %% [markdown]
# **Show TOP 10 Director who gave the hightest number of TV show & Movies**

# %%
df['Director'].value_counts()
# Out:
# Raúl Campos, Jan Suter             18
# Marcus Raboy                       15
# Jay Karas                          14
# Cathy Garcia-Molina                13
# Jay Chapman                        12
#                                    ..
# Robert Osman, Nathanael Wiseman     1
# Ilya Naishuller                     1
# Paresh Mokashi                      1
# Jon Hurwitz, Hayden Schlossberg     1
# Mozez Singh                         1
# Name: Director, Length: 3614, dtype: int64

# %% [markdown]
# **Show Category is Movie, Type is Comedies and Country is United Kingdom**

# %%
df[(df['Category'] == 'Movie') & (df['Type'] == 'Comedies') & (df['Country'] == 'United Kingdom')]
# Out:
#      Show_Id Category                                              Title  \
# 1368   s1369    Movie                                 Christmas Survival
# 1650   s1651    Movie                Dead in a Week (Or Your Money Back)
# 2225   s2226    Movie                                  For Love or Money
# 4210   s4211    Movie   Monty Python Live (Mostly): One Down, Five to Go
# 4213   s4214    Movie           Monty Python: Live at The Hollywood Bowl
# 4781   s4782    Movie  Parrot Sketch Not Included: Twenty Years of Mo...
# 4792   s4793    Movie                                     PATRICK (2019)
# 6109   s6109    Movie                            The Bad Education Movie
# 6947   s6946    Movie                                  The Trip to Spain
#
#                            Director  \
# 1368                  James Dearden
# 1650                    Tom Edmunds
# 2225                    Mark Murphy
# 4210                      Eric Idle
# 4213  Terry Hughes, Ian MacNaughton
# ...

# %% [markdown]
# **How many movies were Tom Cruise cast**

# %%
df[df['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description  year
# 3860  Through chance, human action, past history and...  2020
# 5071  A fast-talking yuppie is forced to slow down w...  2019

# %% [markdown]
# **Type of Rating**

# %%
df['Rating'].nunique()
# Out:
# 14

# %%
df['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# **How many movies got the 'TV-14' in Canada**

# %%
df[(df['Category'] == 'Movie') & (df['Rating'] == 'TV-14') & (df['Country'] == 'Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 34                           Michael Kennedy
# 608                              Jason Stone
# 1506                           Jason Bourque
# 3713  Jennifer Baichwal, Nicholas de Pencier
# 3956                     Jean-François Blais
# ...

# %% [markdown]
# **How many TV shows got the 'R' rating after year 2018**

# %%
df[(df['Category'] == 'TV Show') & (df['Rating'] == 'R') & (df['year']>2018)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, year]
# Index: []

# %% [markdown]
# **Maximum duration of Movies or TV Show on Netflix**

# %%
df['Duration']
# Out:
# 1         93 min
# 2         78 min
# 3         80 min
# 4        123 min
# 5       1 Season
#           ...
# 7780      88 min
# 7782      94 min
# 7783      88 min
# 7784      99 min
# 7785     111 min
# Name: Duration, Length: 4809, dtype: object

# %%
df[['Minute', 'Unit']] = df['Duration'].str.split(' ', expand=True)

# %%
df['Minute'] = df['Minute'].astype('float')

# %%
print(f'Max Duration: { df.Minute.max() } minute')
# Out:
# Max Duration: 253.0 minute

# %% [markdown]
# **Country Max TV show Released**

# %%
df[df['Category'] == 'TV Show']['Country'].value_counts()
# Out:
# United States                                                    27
# United Kingdom                                                   19
# Japan                                                            10
# South Korea                                                      10
# Spain                                                             7
# Taiwan                                                            6
# Turkey                                                            5
# India                                                             5
# Brazil                                                            4
# Canada                                                            3
# Thailand                                                          3
# Nigeria                                                           3
# France                                                            3
# China                                                             2
# ...

# %% [markdown]
# **Sort Values**

# %%
df.sort_values(by='year').head()
# Out:
#      Show_Id Category                        Title  \
# 7115   s7114    Movie         To and From New York
# 5766   s5766    Movie                     Splatter
# 3248   s3249    Movie      Just Another Love Story
# 3840   s3841    Movie  Mad Ron's Prevues from Hell
# 3221   s3222    Movie       Joseph: King of Dreams
#
#                            Director  \
# 7115           Sorin Dan Mihalcescu
# 5766                      Joe Dante
# 3248                   Ole Bornedal
# 3840                     Jim Monaco
# 3221  Rob LaDuca, Robert C. Ramirez
#
#                                                    Cast        Country  \
# 7115  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# 5766  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...  United States
# 3248  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...        Denmark
# 3840  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...  United States
# 3221  Ben Affleck, Mark Hamill, Richard Herd, Mauree...  United States
#
# ...

# %% [markdown]
# **Category TV Show and Type is Dramas**

# %%
df[(df['Category'] == 'Movie') & (df['Type'] == 'Dramas')]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...
